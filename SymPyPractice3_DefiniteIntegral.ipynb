# %%
import sympy

sympy.init_printing(use_latex='mathjax')

x, y = sympy.symbols('x y')
f = x**3 - 3*x**2 + x+6
f
# Out:
#  3      2
# x  - 3⋅x  + x + 6

# %%
#부정 적분

F = sympy.integrate(f)
F
# Out:
#  4         2
# x     3   x
# ── - x  + ── + 6⋅x
# 4         2

# %%
#구해진 미분 전 함수에 정적분 구간을 넣어 계산.

(F.subs(x, 2) - F.subs(x, 0)).evalf() #명령 subs는 substitute(대입)에서 따온 것! ※evalf()명령을 해줘야 수치가 나옴.
# Out:
# 10.0000000000000

# %%
#구적법(quadrature)/수치적분(numerical integration)

def f(x):
    return x**3 - 3*x**2 + x + 6

sp.integrate.quad(f, 0, 2) #구간이 0에서 2. 결과값은 오차가 함께 나옴.
# Out:
# (10.0, 1.1102230246251565e-13)

# %%
from matplotlib.patches import Polygon
import matplotlib.pylab as plt
import matplotlib.font_manager as fm

data = np.random.randint(-100, 100, 50).cumsum()
path = 'C:\\Users\\LG\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBarunpenR.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

def f(x):
    return x**3 - 3*x**2 + x + 6

a, b = 0, 2
x = np.linspace(a-0.5, b+0.5, 50)
y = f(x)

ax = plt.subplot(111)
plt.title("정적분의 예", fontproperties=fontprop)
plt.plot(x, y, 'r', linewidth = 2)

ix = np.linspace(a, b)
iy = f(ix)

verts = [(a,0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor = '0.5')
ax.add_patch(poly)

plt.text(0.5*(a+b), 0.2*(f(a) + f(b)), r"$\int_a^b f(x)dx$",
         horizontalalignment='center', fontsize = 20)
plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])
ax.set_xlim(-2, 4)
ax.set_ylim(0, 8)
plt.show()

# %%
# 다변수 정적분

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
_x = np.arange(12)/2 + 2
_y = np.arange(12)/2
X, Y = np.meshgrid(_x, _y)
x, y = X.ravel(), Y.ravel()
z = x*x - 10*x + y + 50
z0 = np.zeros_like(z)
ax.bar3d(x, y, z0, 0.48, 0.48, z)
ax.set_xlim(0, 10)
ax.set_ylim(-2, 10)
ax.set_zlim(0, 50)
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.title("f(x,y)")
plt.show()

# %%
def f(y, x):
    return np.exp(-x*y)/x**2

sp.integrate.dblquad(f, 1, np.inf, lambda x:0, lambda x:np.inf)

#x의 범위가 1에서 무한대, y의 범위가 0에서 무한대인 함수 exp(-x*y)/x**2의 다차우
# Out:
# (0.4999999999999961, 1.068453874338024e-08)
